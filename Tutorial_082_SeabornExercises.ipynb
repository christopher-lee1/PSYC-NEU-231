# %% [markdown]
# # Seaborn Exercises

# %% [markdown]
# 1) From the "tips" dataset
#     1. add a percentage tip column to the dataset
#     2. visualize the relationship between tip percentage, with day of week and time
#     3. visualize tip ~ day, time, and number of people (which function allows three variables independent variables at once?)

# %%
import seaborn as sns
import pandas as pd

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Add percentage tip column to dataset

# %%
tips['tip_percent'] = (tips['tip'])/(tips['total_bill']) #assuming total bill does not include tip
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_percent
# 0       16.99  1.01  Female     No  Sun  Dinner     2     0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3     0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3     0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2     0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4     0.146808

# %% [markdown]
# 2) Find an interesting trend in the "exercise" dataset

# %%
sns.set(rc={'figure.figsize':(20,12)})

ax = sns.violinplot(x = "size", y = "tip_percent", data = tips, alpha = 0.2)
ax = sns.stripplot(x = "size", y = "tip_percent", data = tips, jitter = True, color = '0.3')

print("Tip percentage seems to be pretty consistent regardless of party size (except when you go by yourself).")
# Out:
# Tip percentage seems to be pretty consistent regardless of party size (except when you go by yourself).
